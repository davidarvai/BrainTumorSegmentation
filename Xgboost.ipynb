# %% [markdown]
# <a href="https://colab.research.google.com/github/davidarvai/DIPLOMADOLGOZAT/blob/main/Xgboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import math
import numpy as np
import nibabel as nib
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Functions for confusion matrix and metrics
def get_custom_confusion_matrix(tumor_type, tn, fp, fn, tp):
    if tumor_type == "Whole Tumor":
        custom_matrix = np.array([[tn, fp, fp, fp],
                                  [fn, tp, tp, tp],
                                  [fn, tp, tp, tp],
                                  [fn, tp, tp, tp]])
    elif tumor_type == "Edema":
        custom_matrix = np.array([[tn, tn, fp, tn],
                                  [tn, tn, fp, tn],
                                  [fn, fn, tp, fn],
                                  [tn, tn, fp, tn]])
    elif tumor_type == "Tumor Core":
        custom_matrix = np.array([[tn, fp, tn, fp],
                                  [fn, tp, fn, tp],
                                  [tn, fp, tn, fp],
                                  [fn, tp, fn, tp]])
    elif tumor_type == "Enhancing Core":
        custom_matrix = np.array([[tn, tn, tn, fp],
                                  [tn, tn, tn, fp],
                                  [tn, tn, tn, fp],
                                  [fn, fn, fn, tp]])
    else:
        custom_matrix = None
    return custom_matrix

# Calculating the elements of the confusion matrix based on the ground truth and the prediction

def compute_confusion(gt_mask, pred_mask):
    tn = np.sum((gt_mask == False) & (pred_mask == False))
    tp = np.sum((gt_mask == True)  & (pred_mask == True))
    fp = np.sum((gt_mask == False) & (pred_mask == True))
    fn = np.sum((gt_mask == True)  & (pred_mask == False))
    return tn, fp, fn, tp

def compute_metrics(tn, fp, fn, tp):
    TPR = tp / (tp + fn) if (tp+fn) > 0 else 0  # True Positive Rate
    TNR = tn / (tn + fp) if (tn+fp) > 0 else 0  # True Negative Rate
    PPV = tp / (tp + fp) if (tp+fp) > 0 else 0  # Precision
    NPV = tn / (tn + fn) if (tn+fn) > 0 else 0  # Negative Predictive Value
    ACC = (tp + tn) / (tp + tn + fp + fn) if (tp+tn+fp+fn) > 0 else 0  # Pontosság
    DS  = (2 * tp) / (2 * tp + fp + fn) if (2 * tp + fp + fn) > 0 else 0  # Dice Score
    return TPR, TNR, PPV, NPV, ACC, DS

# Data loading and preprocessing
def remap_segmentation(seg): # Copy of the input array
    seg_new = np.copy(seg) # A copy of the input array
    seg_new[seg == 4] = 3  # Converting voxels with a value of 4 to 3
    return seg_new

def load_subject_data(subject_path):
    files = os.listdir(subject_path)
    subject_data = {}
    for file in files:
        if file.endswith('.nii') or file.endswith('.nii.gz'):
            lower = file.lower()
            if 'seg' in lower:
                subject_data['seg'] = os.path.join(subject_path, file)
            else:
                for mod in ['t1', 't1ce', 't2', 'flair']:
                    if mod in lower:
                        subject_data[mod] = os.path.join(subject_path, file)
    return subject_data

def load_data_from_dir(data_dir):
    X_list = []
    Y_list = []
    subject_names = []
    subject_dirs = [os.path.join(data_dir, d) for d in os.listdir(data_dir)
                    if os.path.isdir(os.path.join(data_dir, d))]
    subject_dirs.sort()
    for subject_path in subject_dirs:
        data_files = load_subject_data(subject_path)
        if all(mod in data_files for mod in ['t1', 't1ce', 't2', 'flair']) and 'seg' in data_files:
            modality_imgs = []
            for mod in ['t1', 't1ce', 't2', 'flair']:
                img = nib.load(data_files[mod]).get_fdata()
                modality_imgs.append(img)
            X = np.stack(modality_imgs, axis=-1)
            seg = nib.load(data_files['seg']).get_fdata()
            seg = remap_segmentation(seg)
            X_list.append(X)
            Y_list.append(seg)
            subject_names.append(os.path.basename(subject_path))
        else:
            print("Hiányos adatok:", subject_path)
    return X_list, Y_list, subject_names

# Normalizing the input volume to the [0,1] range
def normalize_volume(vol):
    vol = vol.astype(np.float32)
    vol = (vol - np.min(vol)) / (np.max(vol) - np.min(vol) + 1e-8)
    return vol

# Extracting slices (2D)
def extract_slices(volume, seg, slice_axis=2, include_bg_ratio=0.3):
    slices_x = []
    slices_y = []
    D = volume.shape[slice_axis]
    for i in range(D):
        img_slice = volume[:, :, i, :]
        seg_slice = seg[:, :, i]
        if np.sum(seg_slice > 0) > 0.01 * (seg_slice.shape[0] * seg_slice.shape[1]):
            slices_x.append(img_slice)
            slices_y.append(seg_slice)
        else:
            if np.random.rand() < include_bg_ratio:
                slices_x.append(img_slice)
                slices_y.append(seg_slice)
    return slices_x, slices_y

# Pixel sampling from a slice
def sample_pixels_from_slice(img_slice, seg_slice, num_samples=1000, tumor_ratio=0.5):
    H, W, C = img_slice.shape
    tumor_idx = np.argwhere(seg_slice > 0)
    bg_idx = np.argwhere(seg_slice == 0)
    n_tumor = int(num_samples * tumor_ratio)
    n_bg = num_samples - n_tumor

    if len(tumor_idx) < n_tumor:
        tumor_sample = tumor_idx
        n_bg = num_samples - len(tumor_sample)
    else:
        indices = np.random.choice(len(tumor_idx), n_tumor, replace=False)
        tumor_sample = tumor_idx[indices]

    if len(bg_idx) < n_bg:
        bg_sample = bg_idx
    else:
        indices = np.random.choice(len(bg_idx), n_bg, replace=False)
        bg_sample = bg_idx[indices]

    all_idx = np.concatenate([tumor_sample, bg_sample], axis=0)
    np.random.shuffle(all_idx)

    features = []
    labels = []
    for idx in all_idx:
        i, j = idx
        features.append(img_slice[i, j, :])
        labels.append(int(seg_slice[i, j]))
    return np.array(features), np.array(labels)

# Generating training dataset at the pixel level
def create_training_dataset(volumes, segmentations, num_samples_per_slice=1000):
    X_samples = []
    y_samples = []
    for vol, seg in zip(volumes, segmentations):
        slices_img, slices_seg = extract_slices(vol, seg, slice_axis=2, include_bg_ratio=0.3)
        for img_slice, seg_slice in zip(slices_img, slices_seg):
            if img_slice.shape[0] < 10 or img_slice.shape[1] < 10:
                continue
            Xp, yp = sample_pixels_from_slice(img_slice, seg_slice, num_samples=num_samples_per_slice, tumor_ratio=0.5)
            X_samples.append(Xp)
            y_samples.append(yp)
    if len(X_samples) == 0:
        raise ValueError("Nincsenek érvényes szelet minták!")
    X_all = np.concatenate(X_samples, axis=0)
    y_all = np.concatenate(y_samples, axis=0)
    return X_all, y_all

# Function for predicting the entire slice on test data
def predict_volume(model, volume):
    H, W, D, _ = volume.shape
    pred_vol = np.zeros((H, W, D), dtype=np.int32)
    for i in range(D):
        x_slice = volume[:, :, i, :]
        x_flat = x_slice.reshape(-1, x_slice.shape[-1])
        pred_flat = model.predict(x_flat)
        pred_slice = pred_flat.reshape(H, W)
        pred_vol[:, :, i] = pred_slice
    return pred_vol

# Converting the obtained 3D result to a binary mask based on tumor type
def get_binary_mask_3d(segmentation, tumor_type):
    if tumor_type == "Whole Tumor":
        return np.isin(segmentation, [1,2,3])
    elif tumor_type == "Edema":
        return (segmentation == 2)
    elif tumor_type == "Tumor Core":
        return np.isin(segmentation, [1,3])
    elif tumor_type == "Enhancing Core":
        return (segmentation == 3)
    else:
        raise ValueError("Ismeretlen tumor típus!")


if __name__ == "__main__":

    output_dir = "/content/drive/My Drive/Allamvizsga/OutputXgboost"
    os.makedirs(output_dir, exist_ok=True)


    train_dir = "/content/drive/My Drive/Allamvizsga/Data/Teszt/Train"
    test_dir  = "/content/drive/My Drive/Allamvizsga/Data/Teszt/Teszt"

    print("Train adatok betöltése...")
    X_train_vols, Y_train_vols, train_subject_names = load_data_from_dir(train_dir)
    if len(X_train_vols) == 0:
        raise ValueError("Nincsenek betöltött train adatok!")
    X_train_vols = [normalize_volume(vol) for vol in X_train_vols]

    print("Tréning pixel adatok előállítása...")
    X_pixels, y_pixels = create_training_dataset(X_train_vols, Y_train_vols, num_samples_per_slice=1000)
    print("Összes minta:", X_pixels.shape, y_pixels.shape)

    # Train/Validation split
    X_train, X_val, y_train, y_val = train_test_split(X_pixels, y_pixels, test_size=0.2, random_state=42)

    # XGBoost classifier – 4 classes (0, 1, 2, 3)
    model = xgb.XGBClassifier(
        objective='multi:softmax',
        num_class=4,
        use_label_encoder=False,
        eval_metric=['mlogloss', 'merror'],
        verbosity=1,
        random_state=42
    )

    print("XGBoost tréning...")
    eval_set = [(X_train, y_train), (X_val, y_val)]
    model.fit(X_train, y_train, eval_set=eval_set, verbose=True)

    # Extracting metrics collected during training
    evals_result = model.evals_result()

    # Saving learning curves
    # Loss Curve: mlogloss
    plt.figure(figsize=(8,6))
    plt.plot(evals_result['validation_0']['mlogloss'], label='Train Loss')
    plt.plot(evals_result['validation_1']['mlogloss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.ylabel('mlogloss')
    plt.xlabel('Epochs')
    plt.legend()
    plt.savefig(os.path.join(output_dir, 'loss_curve.png'))
    plt.close()

    # Accuracy Curve:
    plt.figure(figsize=(8,6))
    train_acc = [1 - err for err in evals_result['validation_0']['merror']]
    val_acc = [1 - err for err in evals_result['validation_1']['merror']]
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend()
    plt.savefig(os.path.join(output_dir, 'accuracy_curve.png'))
    plt.close()

    # Testing: Predicting the entire 3D map slice by slice
    print("Teszt adatok betöltése...")
    X_test_vols, Y_test_vols, test_subject_names = load_data_from_dir(test_dir)
    if len(X_test_vols) == 0:
        raise ValueError("Nincsenek betöltött teszt adatok!")
    X_test_vols = [normalize_volume(vol) for vol in X_test_vols]

    metrics_rows = []
    output_txt_lines = []
    tumor_types = ["Whole Tumor", "Edema", "Tumor Core", "Enhancing Core"]

    for vol, seg, subj_name in zip(X_test_vols, Y_test_vols, test_subject_names):
        print("Előrejelzés a", subj_name, "subjectön...")
        pred_vol = predict_volume(model, vol)


        for tumor in tumor_types:
            gt_mask = get_binary_mask_3d(seg, tumor)
            pred_mask = get_binary_mask_3d(pred_vol, tumor)
            tn, fp, fn, tp = compute_confusion(gt_mask, pred_mask)
            TPR, TNR, PPV, NPV, ACC, DS = compute_metrics(tn, fp, fn, tp)
            cm = get_custom_confusion_matrix(tumor, tn, fp, fn, tp)

            metrics_rows.append({
                "Name": subj_name,
                "TumorType": tumor,
                "TP": tp,
                "TN": tn,
                "FP": fp,
                "FN": fn,
                "TPR": round(TPR, 3),
                "TNR": round(TNR, 3),
                "PPV": round(PPV, 3),
                "NPV": round(NPV, 3),
                "ACC": round(ACC, 3),
                "DS": round(DS, 3)
            })

            txt_block = f"Mapa neve: {subj_name}\nTumor típus: {tumor}\nKonfúziós mátrix:\n{cm}\n"
            txt_block += f"True Positive Rate (TPR): {round(TPR,3)}\n"
            txt_block += f"True Negative Rate (TNR): {round(TNR,3)}\n"
            txt_block += f"Positive Predictive Value (PPV): {round(PPV,3)}\n"
            txt_block += f"Negative Predictive Value (NPV): {round(NPV,3)}\n"
            txt_block += f"Accuracy (ACC): {round(ACC,3)}\n"
            txt_block += f"Dice Score (DS): {round(DS,3)}\n\n"
            output_txt_lines.append(txt_block)

    # Saving results to a CSV file
    metrics_df = pd.DataFrame(metrics_rows, columns=["Name", "TumorType", "TP", "TN", "FP", "FN", "TPR", "TNR", "PPV", "NPV", "ACC", "DS"])
    csv_path = os.path.join(output_dir, "metrics_output.csv")
    metrics_df.to_csv(csv_path, index=False)
    print("A metrics_output.csv fájl elmentve:", csv_path)

    # Saving results to a TXT file
    txt_path = os.path.join(output_dir, "output.txt")
    with open(txt_path, "w") as f:
        f.write("".join(output_txt_lines))
    print("Az output.txt fájl elmentve:", txt_path)
# Out:
# Train adatok betöltése...
# Tréning pixel adatok előállítása...
# Összes minta: (757000, 4) (757000,)
# XGBoost tréning...
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [18:55:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-mlogloss:0.95471	validation_0-merror:0.09208	validation_1-mlogloss:0.95530	validation_1-merror:0.09293
# [1]	validation_0-mlogloss:0.72646	validation_0-merror:0.08901	validation_1-mlogloss:0.72757	validation_1-merror:0.09030
# [2]	validation_0-mlogloss:0.58154	validation_0-merror:0.08782	validation_1-mlogloss:0.58308	validation_1-merror:0.08890
# [3]	validation_0-mlogloss:0.48277	validation_0-merror:0.08728	validation_1-mlogloss:0.48474	validation_1-merror:0.08862
# [4]	validation_0-mlogloss:0.41408	validation_0-merror:0.08646	validation_1-mlogloss:0.41632	validation_1-merror:0.08764
# [5]	validation_0-mlogloss:0.36248	validation_0-merror:0.08515	validation_1-mlogloss:0.36496	validation_1-merror:0.08651
# [6]	validation_0-mlogloss:0.32510	validation_0-merror:0.08421	validation_1-mlogloss:0.32778	validation_1-merror:0.08536
# [7]	validation_0-mlogloss:0.29800	validation_0-merror:0.08353	validation_1-mlogloss:0.30086	validation_1-merror:0.08476
# [8]	validation_0-mlogloss:0.27745	validation_0-merror:0.08284	validation_1-mlogloss:0.28046	validation_1-merror:0.08365
# [9]	validation_0-mlogloss:0.26261	validation_0-merror:0.08228	validation_1-mlogloss:0.26579	validation_1-merror:0.08317
# [10]	validation_0-mlogloss:0.25005	validation_0-merror:0.08086	validation_1-mlogloss:0.25341	validation_1-merror:0.08186
# [11]	validation_0-mlogloss:0.24029	validation_0-merror:0.08002	validation_1-mlogloss:0.24375	validation_1-merror:0.08083
# [12]	validation_0-mlogloss:0.23344	validation_0-merror:0.07980	validation_1-mlogloss:0.23702	validation_1-merror:0.08085
# [13]	validation_0-mlogloss:0.22781	validation_0-merror:0.07920	validation_1-mlogloss:0.23159	validation_1-merror:0.08050
# [14]	validation_0-mlogloss:0.22312	validation_0-merror:0.07875	validation_1-mlogloss:0.22709	validation_1-merror:0.08008
# [15]	validation_0-mlogloss:0.21992	validation_0-merror:0.07835	validation_1-mlogloss:0.22397	validation_1-merror:0.07956
# [16]	validation_0-mlogloss:0.21743	validation_0-merror:0.07818	validation_1-mlogloss:0.22161	validation_1-merror:0.07941
# [17]	validation_0-mlogloss:0.21428	validation_0-merror:0.07755	validation_1-mlogloss:0.21856	validation_1-merror:0.07892
# [18]	validation_0-mlogloss:0.21208	validation_0-merror:0.07714	validation_1-mlogloss:0.21650	validation_1-merror:0.07841
# [19]	validation_0-mlogloss:0.21062	validation_0-merror:0.07698	validation_1-mlogloss:0.21517	validation_1-merror:0.07837
# [20]	validation_0-mlogloss:0.20909	validation_0-merror:0.07668	validation_1-mlogloss:0.21375	validation_1-merror:0.07810
# [21]	validation_0-mlogloss:0.20758	validation_0-merror:0.07611	validation_1-mlogloss:0.21237	validation_1-merror:0.07764
# [22]	validation_0-mlogloss:0.20628	validation_0-merror:0.07584	validation_1-mlogloss:0.21117	validation_1-merror:0.07738
# [23]	validation_0-mlogloss:0.20506	validation_0-merror:0.07554	validation_1-mlogloss:0.21005	validation_1-merror:0.07715
# [24]	validation_0-mlogloss:0.20398	validation_0-merror:0.07533	validation_1-mlogloss:0.20905	validation_1-merror:0.07692
# [25]	validation_0-mlogloss:0.20260	validation_0-merror:0.07499	validation_1-mlogloss:0.20782	validation_1-merror:0.07660
# [26]	validation_0-mlogloss:0.20144	validation_0-merror:0.07470	validation_1-mlogloss:0.20687	validation_1-merror:0.07637
# [27]	validation_0-mlogloss:0.20041	validation_0-merror:0.07441	validation_1-mlogloss:0.20600	validation_1-merror:0.07617
# [28]	validation_0-mlogloss:0.19938	validation_0-merror:0.07393	validation_1-mlogloss:0.20517	validation_1-merror:0.07592
# [29]	validation_0-mlogloss:0.19845	validation_0-merror:0.07368	validation_1-mlogloss:0.20436	validation_1-merror:0.07567
# [30]	validation_0-mlogloss:0.19786	validation_0-merror:0.07359	validation_1-mlogloss:0.20389	validation_1-merror:0.07559
# [31]	validation_0-mlogloss:0.19676	validation_0-merror:0.07335	validation_1-mlogloss:0.20296	validation_1-merror:0.07535
# [32]	validation_0-mlogloss:0.19574	validation_0-merror:0.07299	validation_1-mlogloss:0.20204	validation_1-merror:0.07505
# [33]	validation_0-mlogloss:0.19455	validation_0-merror:0.07262	validation_1-mlogloss:0.20102	validation_1-merror:0.07468
# [34]	validation_0-mlogloss:0.19326	validation_0-merror:0.07223	validation_1-mlogloss:0.19994	validation_1-merror:0.07430
# [35]	validation_0-mlogloss:0.19260	validation_0-merror:0.07214	validation_1-mlogloss:0.19943	validation_1-merror:0.07416
# [36]	validation_0-mlogloss:0.19225	validation_0-merror:0.07209	validation_1-mlogloss:0.19921	validation_1-merror:0.07409
# [37]	validation_0-mlogloss:0.19159	validation_0-merror:0.07196	validation_1-mlogloss:0.19876	validation_1-merror:0.07401
# [38]	validation_0-mlogloss:0.19114	validation_0-merror:0.07185	validation_1-mlogloss:0.19841	validation_1-merror:0.07406
# [39]	validation_0-mlogloss:0.19032	validation_0-merror:0.07157	validation_1-mlogloss:0.19774	validation_1-merror:0.07379
# [40]	validation_0-mlogloss:0.18997	validation_0-merror:0.07146	validation_1-mlogloss:0.19752	validation_1-merror:0.07376
# [41]	validation_0-mlogloss:0.18965	validation_0-merror:0.07137	validation_1-mlogloss:0.19730	validation_1-merror:0.07375
# [42]	validation_0-mlogloss:0.18905	validation_0-merror:0.07125	validation_1-mlogloss:0.19683	validation_1-merror:0.07354
# [43]	validation_0-mlogloss:0.18817	validation_0-merror:0.07085	validation_1-mlogloss:0.19608	validation_1-merror:0.07331
# [44]	validation_0-mlogloss:0.18761	validation_0-merror:0.07064	validation_1-mlogloss:0.19564	validation_1-merror:0.07326
# [45]	validation_0-mlogloss:0.18718	validation_0-merror:0.07049	validation_1-mlogloss:0.19538	validation_1-merror:0.07291
# [46]	validation_0-mlogloss:0.18676	validation_0-merror:0.07037	validation_1-mlogloss:0.19507	validation_1-merror:0.07287
# [47]	validation_0-mlogloss:0.18615	validation_0-merror:0.07023	validation_1-mlogloss:0.19465	validation_1-merror:0.07275
# [48]	validation_0-mlogloss:0.18588	validation_0-merror:0.07014	validation_1-mlogloss:0.19448	validation_1-merror:0.07269
# [49]	validation_0-mlogloss:0.18561	validation_0-merror:0.07009	validation_1-mlogloss:0.19432	validation_1-merror:0.07261
# [50]	validation_0-mlogloss:0.18545	validation_0-merror:0.07006	validation_1-mlogloss:0.19423	validation_1-merror:0.07264
# [51]	validation_0-mlogloss:0.18520	validation_0-merror:0.07005	validation_1-mlogloss:0.19409	validation_1-merror:0.07259
# [52]	validation_0-mlogloss:0.18456	validation_0-merror:0.06979	validation_1-mlogloss:0.19359	validation_1-merror:0.07244
# [53]	validation_0-mlogloss:0.18433	validation_0-merror:0.06973	validation_1-mlogloss:0.19346	validation_1-merror:0.07242
# [54]	validation_0-mlogloss:0.18390	validation_0-merror:0.06962	validation_1-mlogloss:0.19318	validation_1-merror:0.07243
# [55]	validation_0-mlogloss:0.18358	validation_0-merror:0.06956	validation_1-mlogloss:0.19301	validation_1-merror:0.07242
# [56]	validation_0-mlogloss:0.18325	validation_0-merror:0.06943	validation_1-mlogloss:0.19279	validation_1-merror:0.07236
# [57]	validation_0-mlogloss:0.18290	validation_0-merror:0.06929	validation_1-mlogloss:0.19258	validation_1-merror:0.07220
# [58]	validation_0-mlogloss:0.18256	validation_0-merror:0.06921	validation_1-mlogloss:0.19237	validation_1-merror:0.07228
# [59]	validation_0-mlogloss:0.18207	validation_0-merror:0.06897	validation_1-mlogloss:0.19203	validation_1-merror:0.07211
# [60]	validation_0-mlogloss:0.18173	validation_0-merror:0.06894	validation_1-mlogloss:0.19183	validation_1-merror:0.07198
# [61]	validation_0-mlogloss:0.18158	validation_0-merror:0.06888	validation_1-mlogloss:0.19175	validation_1-merror:0.07192
# [62]	validation_0-mlogloss:0.18129	validation_0-merror:0.06872	validation_1-mlogloss:0.19158	validation_1-merror:0.07183
# [63]	validation_0-mlogloss:0.18096	validation_0-merror:0.06867	validation_1-mlogloss:0.19136	validation_1-merror:0.07178
# [64]	validation_0-mlogloss:0.18074	validation_0-merror:0.06861	validation_1-mlogloss:0.19122	validation_1-merror:0.07176
# [65]	validation_0-mlogloss:0.18047	validation_0-merror:0.06855	validation_1-mlogloss:0.19105	validation_1-merror:0.07169
# [66]	validation_0-mlogloss:0.18023	validation_0-merror:0.06849	validation_1-mlogloss:0.19088	validation_1-merror:0.07159
# [67]	validation_0-mlogloss:0.17997	validation_0-merror:0.06840	validation_1-mlogloss:0.19073	validation_1-merror:0.07159
# [68]	validation_0-mlogloss:0.17959	validation_0-merror:0.06826	validation_1-mlogloss:0.19046	validation_1-merror:0.07149
# [69]	validation_0-mlogloss:0.17933	validation_0-merror:0.06817	validation_1-mlogloss:0.19028	validation_1-merror:0.07137
# [70]	validation_0-mlogloss:0.17890	validation_0-merror:0.06803	validation_1-mlogloss:0.19001	validation_1-merror:0.07132
# [71]	validation_0-mlogloss:0.17858	validation_0-merror:0.06795	validation_1-mlogloss:0.18982	validation_1-merror:0.07123
# [72]	validation_0-mlogloss:0.17813	validation_0-merror:0.06774	validation_1-mlogloss:0.18949	validation_1-merror:0.07110
# [73]	validation_0-mlogloss:0.17784	validation_0-merror:0.06768	validation_1-mlogloss:0.18932	validation_1-merror:0.07104
# [74]	validation_0-mlogloss:0.17762	validation_0-merror:0.06761	validation_1-mlogloss:0.18921	validation_1-merror:0.07107
# [75]	validation_0-mlogloss:0.17750	validation_0-merror:0.06759	validation_1-mlogloss:0.18920	validation_1-merror:0.07101
# [76]	validation_0-mlogloss:0.17730	validation_0-merror:0.06756	validation_1-mlogloss:0.18912	validation_1-merror:0.07097
# [77]	validation_0-mlogloss:0.17712	validation_0-merror:0.06746	validation_1-mlogloss:0.18904	validation_1-merror:0.07098
# [78]	validation_0-mlogloss:0.17692	validation_0-merror:0.06735	validation_1-mlogloss:0.18894	validation_1-merror:0.07098
# [79]	validation_0-mlogloss:0.17656	validation_0-merror:0.06722	validation_1-mlogloss:0.18871	validation_1-merror:0.07094
# [80]	validation_0-mlogloss:0.17629	validation_0-merror:0.06708	validation_1-mlogloss:0.18856	validation_1-merror:0.07075
# [81]	validation_0-mlogloss:0.17594	validation_0-merror:0.06688	validation_1-mlogloss:0.18833	validation_1-merror:0.07071
# [82]	validation_0-mlogloss:0.17558	validation_0-merror:0.06677	validation_1-mlogloss:0.18812	validation_1-merror:0.07062
# [83]	validation_0-mlogloss:0.17524	validation_0-merror:0.06662	validation_1-mlogloss:0.18792	validation_1-merror:0.07057
# [84]	validation_0-mlogloss:0.17503	validation_0-merror:0.06661	validation_1-mlogloss:0.18781	validation_1-merror:0.07055
# [85]	validation_0-mlogloss:0.17487	validation_0-merror:0.06655	validation_1-mlogloss:0.18772	validation_1-merror:0.07058
# [86]	validation_0-mlogloss:0.17476	validation_0-merror:0.06652	validation_1-mlogloss:0.18771	validation_1-merror:0.07060
# [87]	validation_0-mlogloss:0.17462	validation_0-merror:0.06646	validation_1-mlogloss:0.18763	validation_1-merror:0.07061
# [88]	validation_0-mlogloss:0.17442	validation_0-merror:0.06639	validation_1-mlogloss:0.18754	validation_1-merror:0.07055
# [89]	validation_0-mlogloss:0.17432	validation_0-merror:0.06635	validation_1-mlogloss:0.18751	validation_1-merror:0.07059
# [90]	validation_0-mlogloss:0.17414	validation_0-merror:0.06629	validation_1-mlogloss:0.18744	validation_1-merror:0.07055
# [91]	validation_0-mlogloss:0.17400	validation_0-merror:0.06620	validation_1-mlogloss:0.18742	validation_1-merror:0.07046
# [92]	validation_0-mlogloss:0.17377	validation_0-merror:0.06610	validation_1-mlogloss:0.18731	validation_1-merror:0.07038
# [93]	validation_0-mlogloss:0.17353	validation_0-merror:0.06601	validation_1-mlogloss:0.18719	validation_1-merror:0.07033
# [94]	validation_0-mlogloss:0.17331	validation_0-merror:0.06593	validation_1-mlogloss:0.18712	validation_1-merror:0.07028
# [95]	validation_0-mlogloss:0.17308	validation_0-merror:0.06577	validation_1-mlogloss:0.18697	validation_1-merror:0.07028
# [96]	validation_0-mlogloss:0.17284	validation_0-merror:0.06572	validation_1-mlogloss:0.18687	validation_1-merror:0.07028
# [97]	validation_0-mlogloss:0.17271	validation_0-merror:0.06568	validation_1-mlogloss:0.18684	validation_1-merror:0.07024
# [98]	validation_0-mlogloss:0.17241	validation_0-merror:0.06561	validation_1-mlogloss:0.18669	validation_1-merror:0.07026
# [99]	validation_0-mlogloss:0.17222	validation_0-merror:0.06558	validation_1-mlogloss:0.18659	validation_1-merror:0.07020
# Teszt adatok betöltése...
# Előrejelzés a BraTS20_Training_005 subjectön...
# Előrejelzés a BraTS20_Training_055 subjectön...
# Előrejelzés a BraTS20_Training_083 subjectön...
# Előrejelzés a BraTS20_Training_108 subjectön...
# Előrejelzés a BraTS20_Training_118 subjectön...
# Előrejelzés a BraTS20_Training_132 subjectön...
# Előrejelzés a BraTS20_Training_147 subjectön...
# Előrejelzés a BraTS20_Training_151 subjectön...
# Előrejelzés a BraTS20_Training_340 subjectön...
# Előrejelzés a BraTS20_Training_369 subjectön...
# A metrics_output.csv fájl elmentve: /content/drive/My Drive/Allamvizsga/OutputXgboost/metrics_output.csv
# Az output.txt fájl elmentve: /content/drive/My Drive/Allamvizsga/OutputXgboost/output.txt
